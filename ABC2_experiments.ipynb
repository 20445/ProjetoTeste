# %%
load('minimizeABC2.py')

# %%
g, f = minimizeABC2(8,9)

# %%
print g, f
# Out:
# ['GCOe`W', 'H?BDAow'] [5.528767216464254, 5.916079783099616]

# %%
G = Graph(g[1])

# %%
G.show()
# Out:
# Graphics object consisting of 20 graphics primitives

# %%
load('maximizeABC2.py')

# %%
g, f = maximizeABC2(8,9)

# %%
G = Graph(g[1])
G.show()
# Out:
# Graphics object consisting of 20 graphics primitives
